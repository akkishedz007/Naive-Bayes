# %%
import pandas as pd
import numpy as np

# %%
data_train=pd.read_csv('SalaryData_Train(1).csv',squeeze=True)
data_train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
type(data_train)
# Out:
# pandas.core.frame.DataFrame

# %%
data_test=pd.read_csv('SalaryData_Test(1).csv',squeeze=True)
data_test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
data=pd.concat([data_train,data_test])

# %%
data=data.reset_index()

# %%
data
# Out:
#        index  age          workclass   education  educationno  \
# 0          0   39          State-gov   Bachelors           13
# 1          1   50   Self-emp-not-inc   Bachelors           13
# 2          2   38            Private     HS-grad            9
# 3          3   53            Private        11th            7
# 4          4   28            Private   Bachelors           13
# ...      ...  ...                ...         ...          ...
# 45216  15055   33            Private   Bachelors           13
# 45217  15056   39            Private   Bachelors           13
# 45218  15057   38            Private   Bachelors           13
# 45219  15058   44            Private   Bachelors           13
# 45220  15059   35       Self-emp-inc   Bachelors           13
#
#              maritalstatus          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# 1       Married-civ-spouse     Exec-managerial         Husband
# ...

# %%
data=data.drop(['index'],axis=1)

# %%
data
# Out:
#        age          workclass   education  educationno        maritalstatus  \
# 0       39          State-gov   Bachelors           13        Never-married
# 1       50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2       38            Private     HS-grad            9             Divorced
# 3       53            Private        11th            7   Married-civ-spouse
# 4       28            Private   Bachelors           13   Married-civ-spouse
# ...    ...                ...         ...          ...                  ...
# 45216   33            Private   Bachelors           13        Never-married
# 45217   39            Private   Bachelors           13             Divorced
# 45218   38            Private   Bachelors           13   Married-civ-spouse
# 45219   44            Private   Bachelors           13             Divorced
# 45220   35       Self-emp-inc   Bachelors           13   Married-civ-spouse
#
# ...

# %%
string_columns=['workclass','education','maritalstatus','occupation','relationship','race','sex','native','Salary']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
for i in string_columns:
    data[i]=label_encoder.fit_transform(data[i])

# %%
data
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 45216   33          2          9           13              4           9
# 45217   39          2          9           13              0           9
# 45218   38          2          9           13              2           9
# 45219   44          2          9           13              0           0
# 45220   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
sns.barplot(x='education',y='age',hue='Salary',data=data)
# Out:
# <AxesSubplot:xlabel='education', ylabel='age'>

# %%
sns.barplot(x='sex',y='age',hue='Salary',data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
fx,ax=plt.subplots(figsize=(20,15))

sns.barplot(x='hoursperweek',y='age',hue='Salary',data=data)
# Out:
# <AxesSubplot:xlabel='hoursperweek', ylabel='age'>

# %%
data.info()

# %%
data.isnull().sum()

# %%
data.describe()
# Out:
#                 age     workclass     education   educationno  maritalstatus  \
# count  45221.000000  45221.000000  45221.000000  45221.000000   45221.000000
# mean      38.548086      2.204507     10.313217     10.118463       2.585148
# std       13.217981      0.958132      3.816992      2.552909       1.500460
# min       17.000000      0.000000      0.000000      1.000000       0.000000
# 25%       28.000000      2.000000      9.000000      9.000000       2.000000
# 50%       37.000000      2.000000     11.000000     10.000000       2.000000
# 75%       47.000000      2.000000     12.000000     13.000000       4.000000
# max       90.000000      6.000000     15.000000     16.000000       6.000000
#
#          occupation  relationship          race           sex   capitalgain  \
# count  45221.000000  45221.000000  45221.000000  45221.000000  45221.000000
# mean       5.969572      1.412684      3.680281      0.675062   1101.454700
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45221 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            45221 non-null  int64
#  1   workclass      45221 non-null  int32
#  2   education      45221 non-null  int32
#  3   educationno    45221 non-null  int64
#  4   maritalstatus  45221 non-null  int32
#  5   occupation     45221 non-null  int32
#  6   relationship   45221 non-null  int32
#  7   race           45221 non-null  int32
#  8   sex            45221 non-null  int32
#  9   capitalgain    45221 non-null  int64
#  10  capitalloss    45221 non-null  int64
#  11  hoursperweek   45221 non-null  int64
#  12  native         45221 non-null  int32
#  13  Salary         45221 non-null  object
# dtypes: int32(8), int64(5), object(1)
# memory usage: 3.8+ MB

# %%
data1=data.values

x=data1[:,0:13]
y=data1[:,13]

# %%
x
# Out:
# array([[39,  5,  9, ...,  0, 40, 37],
#        [50,  4,  9, ...,  0, 13, 37],
#        [38,  2, 11, ...,  0, 40, 37],
#        ...,
#        [38,  2,  9, ...,  0, 50, 37],
#        [44,  2,  9, ...,  0, 40, 37],
#        [35,  3,  9, ...,  0, 60, 37]], dtype=int64)

# %%
y
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.33, random_state=10)

# %%
x_train
# Out:
# array([[31,  4, 11, ...,  0, 60, 37],
#        [26,  0, 12, ...,  0, 40,  4],
#        [24,  2,  7, ...,  0, 30, 37],
#        ...,
#        [48,  5,  9, ...,  0, 40, 37],
#        [19,  2, 15, ...,  0, 24, 37],
#        [19,  2, 15, ...,  0, 25, 37]], dtype=int64)

# %%
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
x_test
# Out:
# array([[  52,    2,   14, ...,    0,   40,   37],
#        [  46,    2,    3, ...,    0,   40,   24],
#        [  28,    5,   11, ...,    0,   40,   37],
#        ...,
#        [  35,    1,    9, ...,    0,   40,   37],
#        [  34,    2,   11, ...,    0,   45,   37],
#        [  37,    2,    9, ..., 1902,   40,   37]], dtype=int64)

# %%
y_test
# Out:
# array([1, 0, 0, ..., 0, 1, 1], dtype=int64)

# %% [markdown]
# # Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB as GB
from sklearn.metrics import confusion_matrix
classifier=GB()

# %%
classifier.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=classifier.predict(x_test)

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
# accuracy of the model
train_pred=classifier.fit(x_train,y_train).predict(x_train)
test_pred=classifier.fit(x_train,y_train).predict(x_test)

train_acc=np.mean(train_pred==y_train)
test_acc=np.mean(test_pred==y_test)

print('Train_accuracy: %.3f%%'  %  ((train_acc)*100))
print('Test_accuracy: %.3f%%' % ((test_acc)*100))
# Out:
# Train_accuracy: 79.467%
# Test_accuracy: 79.709%

# %%
nr_correct_docs=(y_test==y_pred).sum()
nr_correct_docs
# Out:
# 11895

# %%
nr_incorrect_docs=y_test.size-nr_correct_docs
nr_incorrect_docs
# Out:
# 3028

# %%
from sklearn.metrics import confusion_matrix

confusion_m=confusion_matrix(y_test,y_pred)
confusion_m
# Out:
# array([[10652,   568],
#        [ 2460,  1243]], dtype=int64)

# %%
from sklearn.metrics import f1_score,precision_score

f1score=f1_score(y_test,y_pred)
f1score
# Out:
# 0.45085237577076526

# %% [markdown]
# If f1_score is high accuracy is high if low accuracy is low

# %%
precision_s = precision_score(y_test,y_pred)
precision_s
# Out:
# 0.6863611264494754

# %% [markdown]
# Precision tells us how many of the correctly predicted cases actually turned out to be positive.
# Recall tells us how many of the actual positive cases we were able to predict correctly with our model.

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
fpr,tpr,threshold=roc_curve(y_test,classifier.predict_proba(x_test)[:,1])

#y should be a 1d array, got an array of shape (14923, 2) instead.

# for plotting roc curve we have to find the probability

# %%
auc=roc_auc_score(y_test,y_pred)

# %%
plt.plot(fpr,tpr,color='red',label='logitmodel(area=%0.2f)'%auc)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.show()

# %% [markdown]
# #ROC is a probability curve and AUC represents the degree or measure of separability. It tells how much the model is capable of distinguishing between classes
#
#
# Plotting the true positive rate (TPR) against the false positive rate (FPR). The true positive rate is the proportion of observations that were correctly predicted to be positive out of all positive observations .

# %% [markdown]
# #Multinominal Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB as NB

# %%
Mmodel=NB()
train_pred_mb=Mmodel.fit(x_train,y_train).predict(x_train)
test_pred_mb=Mmodel.fit(x_train,y_train).predict(x_test)


train_acc_mb=np.mean(train_pred_mb==y_train)
test_acc_mb=np.mean(test_pred_mb==y_test)

print('Train_accuracy: %.3f%%'  %  ((train_acc_mb)*100))
print('Test_accuracy: %.3f%%' % ((test_acc_mb)*100))
# Out:
# Train_accuracy: 77.289%
# Test_accuracy: 77.505%

# %% [markdown]
# # It has less accuracy than Gaussian Naive Bayes
